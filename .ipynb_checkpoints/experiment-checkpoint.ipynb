# %%
import yagua

# %%
proj = yagua.read_dir("_yagua_wd_astroalign_/")

# %%
proj.store.mti2  # 0.9553800421305947
# Out:
# 0.9553800421305947

# %%
proj.store._cache
# Out:
# array([0.00916179, 0.00935673, 0.00935673, 0.04210526, 0.04191033,
#        0.04327485, 0.04288499, 0.00701754, 0.03840156, 0.04327485,
#        0.04405458, 0.04424951, 0.04463938, 0.03976608, 0.04366472,
#        0.0417154 , 0.04152047, 0.03040936, 0.04756335, 0.04736842,
#        0.04580897, 0.03703704, 0.02397661, 0.0460039 , 0.04522417,
#        0.04483431, 0.0454191 ])
